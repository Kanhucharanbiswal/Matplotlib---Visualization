# %%
import matplotlib.pyplot as plt

# %%
activities = ['studying', 'playing', 'watching TV', 'sleeping']

# %%
time_spent = [1,2,4,6]
colors = ['blue', 'red', 'yellow', 'pink']
plt.figure(figsize=(6,6))
plt.pie(time_spent, labels=activities, colors=colors, startangle=90, autopct="%1.1f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x22ce2de85f0>,
#   <matplotlib.patches.Wedge at 0x22ce30392e0>,
#   <matplotlib.patches.Wedge at 0x22ce3408860>,
#   <matplotlib.patches.Wedge at 0x22ce340aa80>],
#  [Text(-0.2632472403313852, 1.068035996798755, 'studying'),
#   Text(-0.9052822749848162, 0.6248711888047935, 'playing'),
#   Text(-0.7294348499411245, -0.8233618886561178, 'watching TV'),
#   Text(1.0919797438417667, 0.13259049377413834, 'sleeping')],
#  [Text(-0.14358940381711918, 0.5825650891629571, '7.7%'),
#   Text(-0.4937903318098996, 0.3408388302571601, '15.4%'),
#   Text(-0.3978735545133406, -0.44910648472151876, '30.8%'),
#   Text(0.5956253148227817, 0.07232208751316636, '46.2%')])
